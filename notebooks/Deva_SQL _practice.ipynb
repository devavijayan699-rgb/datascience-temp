# %%
import sqlite3
import pandas as pd

con = sqlite3.connect('C:\\Users\\devav\\OneDrive\\Desktop\\3rd Sem\\project_3.1\\2_IPL_Cricket\\ipl.db')

def q(sql):
    return pd.read_sql_query(sql, con)

# %%
q("""select * 
from venues ;""")
# Out:
#     venue_id                                              venue  \
# 0          1                              M Chinnaswamy Stadium
# 1          2          Rajiv Gandhi International Stadium, Uppal
# 2          3            Maharashtra Cricket Association Stadium
# 3          4             Saurashtra Cricket Association Stadium
# 4          5                             Holkar Cricket Stadium
# ..       ...                                                ...
# 58        59                         Subrata Roy Sahara Stadium
# 59        60   Shaheed Veer Narayan Singh International Stadium
# 60        61                 JSCA International Stadium Complex
# 61        62  Maharaja Yadavindra Singh International Cricke...
# 62        63  Maharaja Yadavindra Singh International Cricke...
#
#               city
# 0        Bangalore
# 1        Hyderabad
# 2             Pune
# 3           Rajkot
# 4           Indore
# ..             ...
# 58            Pune
# 59          Raipur
# ...

# %%
q("""select * 
from matches ;""")
# Out:
#       match_id  season_id  balls_per_over            city  match_date  \
# 0       335982       2008               6       Bangalore  2008-04-18
# 1      1082591       2017               6       Hyderabad  2017-04-05
# 2      1082592       2017               6            Pune  2017-04-06
# 3      1082593       2017               6          Rajkot  2017-04-07
# 4      1082594       2017               6          Indore  2017-04-08
# ...        ...        ...             ...             ...         ...
# 1207   1529282       2026               6           Delhi  2026-04-27
# 1208   1529283       2026               6  New Chandigarh  2026-04-28
# 1209   1529284       2026               6          Mumbai  2026-04-29
# 1210   1529285       2026               6       Ahmedabad  2026-04-30
# 1211   1529286       2026               6          Jaipur  2026-05-01
#
#                  event_name  match_number gender match_type format  ...  \
# ...

# %%
q("""select * 
from deliveries ;""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288221       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288222       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288223       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288224       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288225       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q("""select * 
from players ;""")
# Out:
#      player_id    player_name       bat_style  \
# 0          963     MN Samuels  Right hand Bat
# 1           53      SB Jakati   Left hand Bat
# 2           12      DA Warner   Left hand Bat
# 3          268    RA Tripathi  Right hand Bat
# 4          186       S Nadeem  Right hand Bat
# ..         ...            ...             ...
# 794       8475  Suyash Sharma  Right hand Bat
# 795      45004   D Madushanka  Right hand Bat
# 796      42566  V Suryavanshi   Left hand Bat
# 797         26         N Rana   Left hand Bat
# 798      45986      SU Parakh   Left hand Bat
#
#                                          bowl_style field_pos  \
# 0                                Right arm Offbreak
# 1                            Slow Left arm Orthodox
# 2                                          Legbreak
# 3                                  Right arm Medium
# 4                            Slow Left arm Orthodox
# ..                                              ...       ...
# ...

# %%
q("""select * 
from teams ;""")
# Out:
#     team_id                    team_name
# 0         1  Royal Challengers Bangalore
# 1         2          Sunrisers Hyderabad
# 2         3               Mumbai Indians
# 3         4       Rising Pune Supergiant
# 4         5                Gujarat Lions
# 5         6        Kolkata Knight Riders
# 6       129          Chennai Super Kings
# 7       134             Rajasthan Royals
# 8       252               Delhi Capitals
# 9       494                 Punjab Kings
# 10      614         Lucknow Super Giants
# 11      615               Gujarat Titans
# 12     1068              Deccan Chargers
# 13     1414         Kochi Tuskers Kerala
# 14     1419                Pune Warriors
# 15     3604      Rising Pune Supergiants

# %%
q("""select * from matches limit 10 ;""")
# Out:
#    match_id  season_id  balls_per_over       city  match_date  \
# 0    335982       2008               6  Bangalore  2008-04-18
# 1   1082591       2017               6  Hyderabad  2017-04-05
# 2   1082592       2017               6       Pune  2017-04-06
# 3   1082593       2017               6     Rajkot  2017-04-07
# 4   1082594       2017               6     Indore  2017-04-08
# 5   1082595       2017               6  Bengaluru  2017-04-08
# 6   1082596       2017               6  Hyderabad  2017-04-09
# 7   1082597       2017               6     Mumbai  2017-04-09
# 8   1082598       2017               6     Indore  2017-04-10
# 9   1082599       2017               6       Pune  2017-04-11
#
#               event_name  match_number gender match_type format  ...  \
# 0  Indian Premier League           1.0   male        T20    T20  ...
# 1  Indian Premier League           1.0   male        T20    T20  ...
# 2  Indian Premier League           2.0   male        T20    T20  ...
# ...

# %%
q("""select match_id,city,venue from matches limit 10 ;""")
# Out:
#    match_id       city                                      venue
# 0    335982  Bangalore                      M Chinnaswamy Stadium
# 1   1082591  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2   1082592       Pune    Maharashtra Cricket Association Stadium
# 3   1082593     Rajkot     Saurashtra Cricket Association Stadium
# 4   1082594     Indore                     Holkar Cricket Stadium
# 5   1082595  Bengaluru                      M.Chinnaswamy Stadium
# 6   1082596  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 7   1082597     Mumbai                           Wankhede Stadium
# 8   1082598     Indore                     Holkar Cricket Stadium
# 9   1082599       Pune    Maharashtra Cricket Association Stadium

# %%
q("""select distinct batsman_type from deliveries;""")
# Out:
#      batsman_type
# 0   Left hand Bat
# 1  Right hand Bat
# 2             NaN

# %%
q("""select distinct bowler_type from deliveries;""")
# Out:
#                                        bowler_type
# 0                                 Right arm Medium
# 1                             Left arm Fast medium
# 2                            Right arm Fast medium
# 3                           Slow Left arm Orthodox
# 4                                  Legbreak Googly
# 5                            Right arm Medium fast
# 6                                   Right arm Fast
# 7                                    Left arm Fast
# 8                                  Left arm Medium
# 9                             Left arm Medium fast
# 10                              Right arm Offbreak
# 11                                        Legbreak
# 12                             Left arm Wrist spin
# 13  Right arm Medium, Right arm Offbreak, Legbreak
# 14                    Right arm Offbreak, Legbreak
# 15             Right arm Offbreak, Legbreak Googly
# 16            Right arm Medium, Right arm Offbreak
# ...

# %%
q("""select distinct season from matches;""")
# Out:
#      season
# 0      2008
# 1      2009
# 2      2010
# 3      2011
# 4      2012
# 5      2013
# 6      2014
# 7      2015
# 8      2016
# 9      2017
# 10     2018
# 11     2019
# 12  2020/21
# 13     2021
# 14     2022
# 15     2023
# 16     2024
# 17     2025
# 18     2026

# %%
q("""select distinct team_name from teams;""")
# Out:
#                       team_name
# 0   Royal Challengers Bangalore
# 1           Sunrisers Hyderabad
# 2                Mumbai Indians
# 3        Rising Pune Supergiant
# 4                 Gujarat Lions
# 5         Kolkata Knight Riders
# 6           Chennai Super Kings
# 7              Rajasthan Royals
# 8                Delhi Capitals
# 9                  Punjab Kings
# 10         Lucknow Super Giants
# 11               Gujarat Titans
# 12              Deccan Chargers
# 13         Kochi Tuskers Kerala
# 14                Pune Warriors
# 15      Rising Pune Supergiants

# %%
q("""select match_id,season_id,city,match_winner 
from matches
where match_winner ='Chennai Super Kings';""")
# Out:
#      match_id  season_id       city         match_winner
# 0     1136561       2018     Mumbai  Chennai Super Kings
# 1     1136565       2018    Chennai  Chennai Super Kings
# 2     1136577       2018       Pune  Chennai Super Kings
# 3     1136580       2018  Hyderabad  Chennai Super Kings
# 4     1136584       2018  Bengaluru  Chennai Super Kings
# ..        ...        ...        ...                  ...
# 141   1473494       2025    Kolkata  Chennai Super Kings
# 142   1473504       2025  Ahmedabad  Chennai Super Kings
# 143   1527691       2026    Chennai  Chennai Super Kings
# 144   1529265       2026    Chennai  Chennai Super Kings
# 145   1529276       2026     Mumbai  Chennai Super Kings
#
# [146 rows x 4 columns]

# %%
q("""select match_id,season,city,venue
from matches
where season <=2015;""")
# Out:
#      match_id season        city                                       venue
# 0      335982   2008   Bangalore                       M Chinnaswamy Stadium
# 1      335983   2008  Chandigarh  Punjab Cricket Association Stadium, Mohali
# 2      335984   2008       Delhi                            Feroz Shah Kotla
# 3      335985   2008      Mumbai                            Wankhede Stadium
# 4      335986   2008     Kolkata                                Eden Gardens
# ..        ...    ...         ...                                         ...
# 512    829815   2015   Hyderabad   Rajiv Gandhi International Stadium, Uppal
# 513    829817   2015      Mumbai                            Wankhede Stadium
# 514    829819   2015        Pune     Maharashtra Cricket Association Stadium
# 515    829821   2015      Ranchi          JSCA International Stadium Complex
# 516    829823   2015     Kolkata                                Eden Gardens
#
# [517 rows x 4 columns]

# %%
q("""select match_id,season,city,venue
from matches
where season >= 2015 AND city = 'Bangalore';""")
# Out:
#     match_id season       city                  venue
# 0     829719   2015  Bangalore  M Chinnaswamy Stadium
# 1     829737   2015  Bangalore  M Chinnaswamy Stadium
# 2     829745   2015  Bangalore  M Chinnaswamy Stadium
# 3     829763   2015  Bangalore  M Chinnaswamy Stadium
# 4     829771   2015  Bangalore  M Chinnaswamy Stadium
# 5     829785   2015  Bangalore  M Chinnaswamy Stadium
# 6     829813   2015  Bangalore  M Chinnaswamy Stadium
# 7     980907   2016  Bangalore  M Chinnaswamy Stadium
# 8     980921   2016  Bangalore  M Chinnaswamy Stadium
# 9     980959   2016  Bangalore  M Chinnaswamy Stadium
# 10    980969   2016  Bangalore  M Chinnaswamy Stadium
# 11    980981   2016  Bangalore  M Chinnaswamy Stadium
# 12    980987   2016  Bangalore  M Chinnaswamy Stadium
# 13    980999   2016  Bangalore  M Chinnaswamy Stadium
# 14    981013   2016  Bangalore  M Chinnaswamy Stadium
# 15    981019   2016  Bangalore  M Chinnaswamy Stadium
# ...

# %%
q("""select match_id,season,city,venue
from matches
where season >= 2015 OR city = 'Bangalore';""")
# Out:
#      match_id season            city  \
# 0      335982   2008       Bangalore
# 1     1082591   2017       Hyderabad
# 2     1082592   2017            Pune
# 3     1082593   2017          Rajkot
# 4     1082594   2017          Indore
# ..        ...    ...             ...
# 791   1529282   2026           Delhi
# 792   1529283   2026  New Chandigarh
# 793   1529284   2026          Mumbai
# 794   1529285   2026       Ahmedabad
# 795   1529286   2026          Jaipur
#
#                                                  venue
# 0                                M Chinnaswamy Stadium
# 1            Rajiv Gandhi International Stadium, Uppal
# 2              Maharashtra Cricket Association Stadium
# 3               Saurashtra Cricket Association Stadium
# 4                               Holkar Cricket Stadium
# ..                                                 ...
# 791                        Arun Jaitley Stadium, Delhi
# 792  Maharaja Yadavindra Singh International Cricke...
# ...

# %%
q("""SELECT match_winner,season
FROM matches
where season >= 2010 AND match_winner = 'Royal Challengers Bangalore';""")
# Out:
#                     match_winner season
# 0    Royal Challengers Bangalore   2010
# 1    Royal Challengers Bangalore   2010
# 2    Royal Challengers Bangalore   2010
# 3    Royal Challengers Bangalore   2010
# 4    Royal Challengers Bangalore   2010
# ..                           ...    ...
# 121  Royal Challengers Bangalore   2026
# 122  Royal Challengers Bangalore   2026
# 123  Royal Challengers Bangalore   2026
# 124  Royal Challengers Bangalore   2026
# 125  Royal Challengers Bangalore   2026
#
# [126 rows x 2 columns]

# %%
q("""select match_id,city,venue 
from matches 
where season >= 2015 
order by city ;""")
# Out:
#      match_id           city  \
# 0     1216493            NaN
# 1     1216495            NaN
# 2     1216496            NaN
# 3     1216498            NaN
# 4     1216500            NaN
# ..        ...            ...
# 749   1181767  Visakhapatnam
# 750   1422131  Visakhapatnam
# 751   1422134  Visakhapatnam
# 752   1473441  Visakhapatnam
# 753   1473447  Visakhapatnam
#
#                                                  venue
# 0                  Dubai International Cricket Stadium
# 1                              Sharjah Cricket Stadium
# 2                              Sharjah Cricket Stadium
# 3                  Dubai International Cricket Stadium
# 4                              Sharjah Cricket Stadium
# ..                                                 ...
# 749  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 750  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 751  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# ...

# %%
q("""select match_id,city,venue 
from matches 
where season >= 2015 
order by match_id DESC ;""")
# Out:
#      match_id            city  \
# 0     1529286          Jaipur
# 1     1529285       Ahmedabad
# 2     1529284          Mumbai
# 3     1529283  New Chandigarh
# 4     1529282           Delhi
# ..        ...             ...
# 749    829713         Kolkata
# 750    829711         Chennai
# 751    829709            Pune
# 752    829707         Chennai
# 753    829705         Kolkata
#
#                                                  venue
# 0                       Sawai Mansingh Stadium, Jaipur
# 1                     Narendra Modi Stadium, Ahmedabad
# 2                             Wankhede Stadium, Mumbai
# 3    Maharaja Yadavindra Singh International Cricke...
# 4                          Arun Jaitley Stadium, Delhi
# ..                                                 ...
# 749                                       Eden Gardens
# 750                    MA Chidambaram Stadium, Chepauk
# 751            Maharashtra Cricket Association Stadium
# ...

# %%
q("""select match_id,city,venue 
from matches 
where season >= 2015 
order by match_id ASC ;""")
# Out:
#      match_id            city  \
# 0      829705         Kolkata
# 1      829707         Chennai
# 2      829709            Pune
# 3      829711         Chennai
# 4      829713         Kolkata
# ..        ...             ...
# 749   1529282           Delhi
# 750   1529283  New Chandigarh
# 751   1529284          Mumbai
# 752   1529285       Ahmedabad
# 753   1529286          Jaipur
#
#                                                  venue
# 0                                         Eden Gardens
# 1                      MA Chidambaram Stadium, Chepauk
# 2              Maharashtra Cricket Association Stadium
# 3                      MA Chidambaram Stadium, Chepauk
# 4                                         Eden Gardens
# ..                                                 ...
# 749                        Arun Jaitley Stadium, Delhi
# 750  Maharaja Yadavindra Singh International Cricke...
# 751                           Wankhede Stadium, Mumbai
# ...

# %%
q("""select match_id,city,venue 
from matches 
where season >= 2015 
order by city ASC ;""")
# Out:
#      match_id           city  \
# 0     1216493            NaN
# 1     1216495            NaN
# 2     1216496            NaN
# 3     1216498            NaN
# 4     1216500            NaN
# ..        ...            ...
# 749   1181767  Visakhapatnam
# 750   1422131  Visakhapatnam
# 751   1422134  Visakhapatnam
# 752   1473441  Visakhapatnam
# 753   1473447  Visakhapatnam
#
#                                                  venue
# 0                  Dubai International Cricket Stadium
# 1                              Sharjah Cricket Stadium
# 2                              Sharjah Cricket Stadium
# 3                  Dubai International Cricket Stadium
# 4                              Sharjah Cricket Stadium
# ..                                                 ...
# 749  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 750  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 751  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# ...

# %%
q("""select match_id,city,venue 
from matches 
where season >= 2015 
order by city DESC ;""")
# Out:
#      match_id           city  \
# 0      829727  Visakhapatnam
# 1      829731  Visakhapatnam
# 2      829743  Visakhapatnam
# 3      980973  Visakhapatnam
# 4      980979  Visakhapatnam
# ..        ...            ...
# 749   1216544            NaN
# 750   1216546            NaN
# 751   1216547            NaN
# 752   1237177            NaN
# 753   1237181            NaN
#
#                                                  venue
# 0    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 1    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 2    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 3    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 4    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# ..                                                 ...
# 749                Dubai International Cricket Stadium
# 750                Dubai International Cricket Stadium
# 751                Dubai International Cricket Stadium
# ...

# %%
q("""SELECT COUNT(DISTINCT venue) AS venue
FROM matches""")
# Out:
#    venue
# 0     59

# %%
q("""SELECT COUNT(*) AS matches
FROM matches""")
# Out:
#    matches
# 0     1212

# %%
q("""SELECT venue, COUNT(*) AS match_count
FROM matches
GROUP BY venue""")
# Out:
#                                                 venue  match_count
# 0                                Arun Jaitley Stadium           14
# 1                         Arun Jaitley Stadium, Delhi           27
# 2                                    Barabati Stadium            7
# 3                 Barsapara Cricket Stadium, Guwahati            8
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...           26
# 5                                   Brabourne Stadium           10
# 6                           Brabourne Stadium, Mumbai           17
# 7                                        Buffalo Park            3
# 8                               De Beers Diamond Oval            3
# 9                          Dr DY Patil Sports Academy           17
# 10                 Dr DY Patil Sports Academy, Mumbai           20
# 11  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...           13
# 12  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...            4
# ...

# %%
q("""SELECT match_Winner, COUNT(*) AS WINNER
FROM matches
GROUP BY match_Winner
ORDER BY WINNER DESC""")
# Out:
#                    match_winner  WINNER
# 0                Mumbai Indians     155
# 1           Chennai Super Kings     146
# 2   Royal Challengers Bangalore     139
# 3         Kolkata Knight Riders     137
# 4           Sunrisers Hyderabad     132
# 5                  Punjab Kings     130
# 6                Delhi Capitals     126
# 7              Rajasthan Royals     125
# 8                Gujarat Titans      42
# 9          Lucknow Super Giants      33
# 10       Rising Pune Supergiant      15
# 11                Pune Warriors      13
# 12                Gujarat Lions      13
# 13         Kochi Tuskers Kerala       6

# %%
q("""SELECT bowler,COUNT(*) AS delivery_count
FROM deliveries
GROUP BY bowler
HAVING delivery_count > 1000;""")
# Out:
#                bowler  delivery_count
# 0            A Mishra            3444
# 1             A Nehra            1974
# 2            A Nortje            1169
# 3            AB Dinda            1589
# 4          AD Russell            1885
# ..                ...             ...
# 80           VR Aaron            1065
# 81  Washington Sundar            1162
# 82          YK Pathan            1184
# 83          YS Chahal            4068
# 84             Z Khan            2276
#
# [85 rows x 2 columns]

# %%
q("""select lower(bowler), count(*) as deliveries
from deliveries
group by lower(bowler)""")
# Out:
#       lower(bowler)  deliveries
# 0    a ashish reddy         270
# 1          a badoni          41
# 2        a chandila         234
# 3       a choudhary         108
# 4       a dananjaya          25
# ..              ...         ...
# 563       ys chahal        4068
# 564   yudhvir singh         145
# 565    yuvraj singh         882
# 566          z khan        2276
# 567  zeeshan ansari         209
#
# [568 rows x 2 columns]

# %%
q("""select venue, count(*) as matches
from matches
WHERE venue ='Buffalo park' OR venue ='Eden Gardens'
group by venue""")
# Out:
#           venue  matches
# 0  Eden Gardens       77

# %%
q("""SELECT batter, COUNT(*) AS deliveries
FROM deliveries
GROUP BY batter
ORDER BY deliveries DESC;""")
# Out:
#              batter  deliveries
# 0           V Kohli        6942
# 1         RG Sharma        5561
# 2          S Dhawan        5483
# 3         DA Warner        4849
# 4         AM Rahane        4259
# ..              ...         ...
# 722     Sunny Gupta           1
# 723          U Kaul           1
# 724  V Pratap Singh           1
# 725   Y Prithvi Raj           1
# 726      YA Abdulla           1
#
# [727 rows x 2 columns]

# %%
q("""
SELECT m.match_id, m.city, m.venue
FROM matches AS m
JOIN venues AS v
ON m.venue = v.venue
""")
# Out:
#       match_id            city  \
# 0       335982       Bangalore
# 1      1082591       Hyderabad
# 2      1082592            Pune
# 3      1082593          Rajkot
# 4      1082594          Indore
# ...        ...             ...
# 1311   1529282           Delhi
# 1312   1529283  New Chandigarh
# 1313   1529284          Mumbai
# 1314   1529285       Ahmedabad
# 1315   1529286          Jaipur
#
#                                                   venue
# 0                                 M Chinnaswamy Stadium
# 1             Rajiv Gandhi International Stadium, Uppal
# 2               Maharashtra Cricket Association Stadium
# 3                Saurashtra Cricket Association Stadium
# 4                                Holkar Cricket Stadium
# ...                                                 ...
# 1311                        Arun Jaitley Stadium, Delhi
# 1312  Maharaja Yadavindra Singh International Cricke...
# 1313                           Wankhede Stadium, Mumbai
# ...

# %%
q("""select d.batter, p.bat_style
from deliveries as d
join players as p on p.player_name = d.batter
""")
# Out:
#             batter       bat_style
# 0       MN Samuels  Right hand Bat
# 1       MN Samuels  Right hand Bat
# 2       MN Samuels  Right hand Bat
# 3       MN Samuels  Right hand Bat
# 4       MN Samuels  Right hand Bat
# ...            ...             ...
# 288221      N Rana   Left hand Bat
# 288222      N Rana   Left hand Bat
# 288223      N Rana   Left hand Bat
# 288224   SU Parakh   Left hand Bat
# 288225   SU Parakh   Left hand Bat
#
# [288226 rows x 2 columns]

# %%
q("""
SELECT venue
FROM venues
EXCEPT
SELECT DISTINCT venue
FROM matches
""")
# Out:
# Empty DataFrame
# Columns: [venue]
# Index: []

# %%
q("""SELECT count(distinct batter)
FROM deliveries
WHERE batter not in (SELECT player_name FROM players);""")
# Out:
#    count(distinct batter)
# 0                       0

# %%
q("""select count(*) as total ,
sum(case when city is null then 1 else 0 end) as missing
from matches""")
# Out:
#    total  missing
# 0   1212       51

# %%
q("""select count(*) as total ,
sum(case when city is null then 1 else 0 end) as missing
from venues""")
# Out:
#    total  missing
# 0     63        2

# %%
q("""select count(distinct venue) as venues 
from matches""")
# Out:
#    venues
# 0      59

# %%
q("""
SELECT
    COUNT(*) AS total,
    SUM(CASE WHEN city IS NULL THEN 1 ELSE 0 END) AS null_count,
    SUM(CASE WHEN city ='' THEN 1 ELSE 0 END) AS empty_count , 
    SUM(CASE WHEN TRIM(city) ='' AND city <> '' THEN 1 ELSE 0 END) AS spaces
FROM matches;""")
# Out:
#    total  null_count  empty_count  spaces
# 0   1212          51            0       0

# %%
q("""select count (distinct
case when instr(venue,',')>0
then trim(substr(venue,1,instr(venue,',')-1))
else trim (venue)end) as after_coma
from matches;""")
# Out:
#    after_coma
# 0          42

# %%
q("""select count (distinct venue) as distinct_venue
from matches;""")
# Out:
#    distinct_venue
# 0              59

# %%
q("""select count(*) as rows,
count (distinct venue) as distinct_venues
from venues;""")
# Out:
#    rows  distinct_venues
# 0    63               59

# %%
q("""select venue,count(*) as n
from venues
group by venue
having count(*) > 1;""")
# Out:
#                                                venue  n
# 0                 Dr DY Patil Sports Academy, Mumbai  2
# 1                Dubai International Cricket Stadium  2
# 2  Maharaja Yadavindra Singh International Cricke...  2
# 3                            Sharjah Cricket Stadium  2

# %%
q("""select result,count(*) as n
from matches
group by result;""")
# Out:
#       result     n
# 0  no result     9
# 1        tie    16
# 2        win  1187

# %%
select match_id,season,result,match_winner
from matches
where result = 'no result' ;
