# %%
import sqlite3
import pandas as pd 
con=sqlite3.connect('C:\\Users\\devav\\OneDrive\\Desktop\\3rd Sem\\project_3.1\\2_IPL_Cricket\\ipl.db')

def q(sql):
    return pd.read_sql(sql,con)

# %%
q("""select * from matches;""")
# Out:
#       match_id  season_id  balls_per_over            city  match_date  \
# 0       335982       2008               6       Bangalore  2008-04-18
# 1      1082591       2017               6       Hyderabad  2017-04-05
# 2      1082592       2017               6            Pune  2017-04-06
# 3      1082593       2017               6          Rajkot  2017-04-07
# 4      1082594       2017               6          Indore  2017-04-08
# ...        ...        ...             ...             ...         ...
# 1207   1529282       2026               6           Delhi  2026-04-27
# 1208   1529283       2026               6  New Chandigarh  2026-04-28
# 1209   1529284       2026               6          Mumbai  2026-04-29
# 1210   1529285       2026               6       Ahmedabad  2026-04-30
# 1211   1529286       2026               6          Jaipur  2026-05-01
#
#                  event_name  match_number gender match_type format  ...  \
# ...

# %%
def run_sql_file(path):
    with open(path,'r')as f:
        script=f.read()
    con.executescript(script)
    con.commit()
    print('ran',path)

# %%
run_sql_file(r'C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\Test.sql')
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\Test.sql

# %%
run_sql_file('C:\\Users\\devav\\OneDrive\\Desktop\\3rd Sem\\project_3.1\\sql\\practice\\01_nulls_and_blank.sql')
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\01_nulls_and_blank.sql

# %%
q("""SELECT COUNT (*) AS blank_before
FROM players
WHERE TRIM(field_pos) = '';""")
# Out:
#    blank_before
# 0           612

# %%
q("""SELECT COUNT(*) AS null_after
FROM v_player_clean
WHERE field_pos_clean IS NULL;""")
# Out:
#    null_after
# 0         700

# %%
q("""select distinct team_name
from teams
order by team_name;""")
# Out:
#                       team_name
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13      Rising Pune Supergiants
# 14  Royal Challengers Bangalore
# 15          Sunrisers Hyderabad

# %%
q("""select distinct team_name_clean
from v_teams_clean
order by team_name_clean;""")
# Out:
#                 team_name_clean
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14          Sunrisers Hyderabad

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\02_merge_categories.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\02_merge_categories.sql

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\03_venue_names.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\03_venue_names.sql

# %%
q("""SELECT venue,COUNT(*) AS matches
FROM matches
WHERE venue IN('Wankhede Stadium','Wankhede Stadium, Mumbai')
GROUP BY venue;""")
# Out:
#                       venue  matches
# 0          Wankhede Stadium       73
# 1  Wankhede Stadium, Mumbai       57

# %%
q("""SELECT venue ,COUNT(*) AS matches
FROM matches
GROUP BY VENUE
ORDER BY matches DESC
LIMIT 10;""")
# Out:
#                                        venue  matches
# 0                               Eden Gardens       77
# 1                           Wankhede Stadium       73
# 2                      M Chinnaswamy Stadium       65
# 3                           Feroz Shah Kotla       60
# 4                   Wankhede Stadium, Mumbai       57
# 5  Rajiv Gandhi International Stadium, Uppal       49
# 6            MA Chidambaram Stadium, Chepauk       48
# 7                     Sawai Mansingh Stadium       47
# 8        Dubai International Cricket Stadium       46
# 9   MA Chidambaram Stadium, Chepauk, Chennai       38

# %%
q("""SELECT venue_clean ,COUNT(*) AS matches
FROM v_matches_venue
GROUP BY venue_clean
ORDER BY matches DESC
LIMIT 5;""")
# Out:
#                           venue_clean  matches
# 0                    Wankhede Stadium      130
# 1               M Chinnaswamy Stadium      104
# 2                        Eden Gardens      104
# 3              MA Chidambaram Stadium       95
# 4  Rajiv Gandhi International Stadium       87

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\04_dedupe_venues.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\04_dedupe_venues.sql

# %%
q("""SELECT COUNT(*) AS rows,COUNT(DISTINCT venue) AS distinct_venues
FROM venues;""")
# Out:
#    rows  distinct_venues
# 0    63               59

# %%
q("""SELECT COUNT(*), venue,city
FROM venues
GROUP BY venue
ORDER BY COUNT(*)
LIMIT 10;""")
# Out:
#    COUNT(*)                                              venue         city
# 0         1                               Arun Jaitley Stadium        Delhi
# 1         1                        Arun Jaitley Stadium, Delhi        Delhi
# 2         1                                   Barabati Stadium      Cuttack
# 3         1                Barsapara Cricket Stadium, Guwahati     Guwahati
# 4         1  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...      Lucknow
# 5         1                                  Brabourne Stadium       Mumbai
# 6         1                          Brabourne Stadium, Mumbai       Mumbai
# 7         1                                       Buffalo Park  East London
# 8         1                              De Beers Diamond Oval    Kimberley
# 9         1                         Dr DY Patil Sports Academy       Mumbai

# %%
q("""SELECT COUNT(*) AS rows,COUNT(DISTINCT venue) AS names
FROM v_venues_clean;""")
# Out:
#    rows  names
# 0    59     59

# %%
q("""SELECT COUNT(*), venue,city
FROM v_venues_clean
GROUP BY venue
ORDER BY COUNT(*) DESC
LIMIT 10;""")
# Out:
#    COUNT(*)                                             venue            city
# 0         1                  Zayed Cricket Stadium, Abu Dhabi       Abu Dhabi
# 1         1                          Wankhede Stadium, Mumbai          Mumbai
# 2         1                                  Wankhede Stadium          Mumbai
# 3         1      Vidarbha Cricket Association Stadium, Jamtha          Nagpur
# 4         1                                   SuperSport Park       Centurion
# 5         1                        Subrata Roy Sahara Stadium            Pune
# 6         1                                  St George's Park  Port Elizabeth
# 7         1                              Sheikh Zayed Stadium       Abu Dhabi
# 8         1                           Sharjah Cricket Stadium         Sharjah
# 9         1  Shaheed Veer Narayan Singh International Stadium          Raipur

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\05_city_fallback.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\05_city_fallback.sql

# %%
q("""
SELECT
    venue,
    COUNT(*) AS no_city
FROM matches
WHERE city IS NULL
GROUP BY venue;
""")
# Out:
#                                  venue  no_city
# 0  Dubai International Cricket Stadium       33
# 1              Sharjah Cricket Stadium       18

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\06_season_year.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\06_season_year.sql

# %%
q("""SELECT DISTINCT season,season_year
FROM v_season WHERE season = '2020/21';""")
# Out:
#     season  season_year
# 0  2020/21         2020

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\07_win_definition.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\07_win_definition.sql

# %%
run_sql_file(r"C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\08_matches_clean.sql")
# Out:
# ran C:\Users\devav\OneDrive\Desktop\3rd Sem\project_3.1\sql\practice\08_matches_clean.sql

# %%
q("""select * from matches_clean;""")
# Out:
#       match_id                                        venue_clean  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591                 Rajiv Gandhi International Stadium
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1207   1529282                               Arun Jaitley Stadium
# 1208   1529283  Maharaja Yadavindra Singh International Cricke...
# 1209   1529284                                   Wankhede Stadium
# 1210   1529285                              Narendra Modi Stadium
# 1211   1529286                             Sawai Mansingh Stadium
#
#           city_clean  season_year result                 match_winner  \
# 0          Bangalore         2008    win        Kolkata Knight Riders
# ...

# %%
import ast
import pandas as pd

d = pd.read_sql(
    "SELECT * FROM deliveries WHERE fielders_involved IS NOT NULL",
    con
)

d['fielders'] = d['fielders_involved'].apply(ast.literal_eval)

d = d.explode('fielders')

d['fielders'].value_counts().head(5)
# Out:
# fielders
# MS Dhoni          258
# KD Karthik        228
# RV Uthappa        169
# AB de Villiers    148
# V Kohli           142
# Name: count, dtype: int64
